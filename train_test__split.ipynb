# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthm04/ComputerVision_0_to_Hero/blob/main/train_test__split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.xlabel('Mileage')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.xlabel('Age(yrs)')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
X=df[['Mileage','Age(yrs)']]#independent variables- double brackets!
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2,random_state=10)##no. 10 indicates this type of random state

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([20474.0745775 , 16352.07892168, 25174.14834912, 27197.42175439])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.7332339593090147
