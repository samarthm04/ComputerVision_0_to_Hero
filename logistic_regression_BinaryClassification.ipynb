# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthm04/ComputerVision_0_to_Hero/blob/main/logistic_regression_BinaryClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Logistic Regression
# Quite useful in classification problems

# %% [markdown]
# ## Types of Classification
# 1.   Binary Classification
# 2.   Multiclass Classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1) Binary Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("insurance_data.csv")

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'],df['bought_insurance'],marker='*', color='green')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(df[['age']],df['bought_insurance'],train_size=0.9)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0
